# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
len(X_train)
# Out:
# 60000

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
plt.matshow(X_train[0])

# %%
plt.matshow(X_train[5])

# %%
y_train[5]
# Out:
# 2

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4623 - accuracy: 0.8803
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3032 - accuracy: 0.9150
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2831 - accuracy: 0.9207
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2724 - accuracy: 0.9235
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2666 - accuracy: 0.9263
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2621 - accuracy: 0.9274
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2581 - accuracy: 0.9290
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2551 - accuracy: 0.9294
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2533 - accuracy: 0.9300
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2512 - accuracy: 0.9306

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2633 - accuracy: 0.9270
# [0.2633027136325836, 0.9269999861717224]

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2786 - accuracy: 0.9196
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1290 - accuracy: 0.9618
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0892 - accuracy: 0.9730
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0680 - accuracy: 0.9792
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0526 - accuracy: 0.9835

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0785 - accuracy: 0.9769
# [0.07848081737756729, 0.9768999814987183]
